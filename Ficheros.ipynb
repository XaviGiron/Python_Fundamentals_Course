# %%
import pandas as pd

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
# !pip install numpy

# %%
import numpy as np

# %%
# !pip install csv
# Out:
# ERROR: Could not find a version that satisfies the requirement csv (from versions: none)
# ERROR: No matching distribution found for csv

# %%
import csv

# %%
datos = pd.read_csv("athlete_events.csv")

# %%
datos
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
datos["Name"].unique().tolist()
# Out:
# ['A Dijiang',
#  'A Lamusi',
#  'Gunnar Nielsen Aaby',
#  'Edgar Lindenau Aabye',
#  'Christine Jacoba Aaftink',
#  'Per Knut Aaland',
#  'John Aalberg',
#  'Cornelia "Cor" Aalten (-Strannood)',
#  'Antti Sami Aalto',
#  'Einar Ferdinand "Einari" Aalto',
#  'Jorma Ilmari Aalto',
#  'Jyri Tapani Aalto',
#  'Minna Maarit Aalto',
#  'Pirjo Hannele Aalto (Mattila-)',
#  'Arvo Ossian Aaltonen',
#  'Juhamatti Tapio Aaltonen',
#  'Paavo Johannes Aaltonen',
#  'Timo Antero Aaltonen',
#  'Win Valdemar Aaltonen',
#  'Kjetil Andr Aamodt',
#  'Ragnhild Margrethe Aamodt',
#  'Andreea Aanei',
#  'Fritz Aanes',
#  'Nils Egil Aaness',
#  'Alf Lied Aanning',
#  'Agnes Erika Aanonsen (-Eyde)',
#  'Johan Aantjes',
#  'Jan-Erik Aarberg',
#  'Willemien Aardenburg',
#  'Pepijn Aardewijn',
#  'Evald rma (rman-)',
#  'Olav Augunson Aarnes',
#  'Mika Lauri Aarnikka',
#  'Jamale (Djamel-) Aarrass (Ahrass-)',
#  'Dagfinn Sverre Aarskog',
#  'Stefan Remco Aartsen',
#  'Ann Kristin Aarnes',
#  'Karl Jan Aas',
# ...

# %%
datos["Sport"] == "Tennis"
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 271111    False
# 271112    False
# 271113    False
# 271114    False
# 271115    False
# Name: Sport, Length: 271116, dtype: bool

# %%
datos["Sex"].count()
# Out:
# 271116

# %%
datos["Age"].min()
# Out:
# 10.0

# %%
datos["Age"].max()
# Out:
# 97.0

# %%
datos.sort_values(by=["Age"])
# Out:
#             ID                                             Name Sex   Age  \
# 142882   71691                               Dimitrios Loundras   M  10.0
# 252231  126307                                     Liana Vicens   F  11.0
# 101378   51268                                   Beatrice Hutiu   F  11.0
# 140650   70616                                       Liu Luyang   F  11.0
# 237141  118925  Megan Olwen Devenish Taylor (-Mandeville-Ellis)   F  11.0
# ...        ...                                              ...  ..   ...
# 270679  135368                                Antonio A. Zucchi   M   NaN
# 270774  135416                                        Star Zulu   M   NaN
# 270793  135426                                     Max Zumstein   M   NaN
# 270804  135434                               Edmundo Ziga Erraz   M   NaN
# 270805  135435                                       Faelo Ziga   M   NaN
#
#         Height  Weight                           Team  NOC        Games  Year  \
# ...

# %%
datos[datos['Age'].notna()]
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
datos["Age"].min() and datos[datos["Medal"] == "Gold"]
# Out:
#             ID                                 Name Sex   Age  Height  Weight  \
# 3            4                 Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 42          17              Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 44          17              Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 48          17              Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 60          20                   Kjetil Andr Aamodt   M  20.0   176.0    85.0
# ...        ...                                  ...  ..   ...     ...     ...
# 270981  135503                      Zurab Zviadauri   M  23.0   182.0    90.0
# 271009  135520                          Julia Zwehl   F  28.0   167.0    60.0
# 271016  135523       Ronald Ferdinand "Ron" Zwerver   M  29.0   200.0    93.0
# 271049  135545                      Henk Jan Zwolle   M  31.0   197.0    93.0
# 271076  135553  Galina Ivanovna Zybina (-Fyodorova)   F  21.0   168.0    80.0
#
# ...

# %%
datos["Age"].max() and datos[datos["Medal"] == "Gold"]
# Out:
#             ID                                 Name Sex   Age  Height  Weight  \
# 3            4                 Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 42          17              Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 44          17              Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 48          17              Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 60          20                   Kjetil Andr Aamodt   M  20.0   176.0    85.0
# ...        ...                                  ...  ..   ...     ...     ...
# 270981  135503                      Zurab Zviadauri   M  23.0   182.0    90.0
# 271009  135520                          Julia Zwehl   F  28.0   167.0    60.0
# 271016  135523       Ronald Ferdinand "Ron" Zwerver   M  29.0   200.0    93.0
# 271049  135545                      Henk Jan Zwolle   M  31.0   197.0    93.0
# 271076  135553  Galina Ivanovna Zybina (-Fyodorova)   F  21.0   168.0    80.0
#
# ...
